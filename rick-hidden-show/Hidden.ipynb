# %%
import cv2 as cv
import matplotlib.pyplot as plt
import matplotlib.pyplot
img = cv.imread(hidden)

# %%
hidden_image = Image.open("/content/hidden_rick.png")
original_image = Image.open("/content/original_rick.png")

# %%
hidden_image_n  = (np.array(hidden_image)/ 256)[:,:,:3]
original_image_n = (np.array(original_image) /256)[:,:,:3]

# %% [markdown]
# ## Get the deffercence between hidden and original image

# %%
dif = hidden_image_n - original_image_n

# %%
plt.imshow(dif)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Apply DCT to the difference :

# %%
from scipy.fftpack import dct
def dct2(a):
    return dct(a, axis=1, norm='backward')
imF = dct2(dif)

plt.figure(figsize=(20,20))
plt.subplot(121), plt.imshow(imF), plt.axis('off')

plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
